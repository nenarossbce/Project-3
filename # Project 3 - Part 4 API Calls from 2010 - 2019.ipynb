# %% [markdown]
# # Project 3 - Part 2 Extract from TMDB

# %% [markdown]
# Source: https://www.themoviedb.org/

# %%
#login with api credentials for tmbd
import json
with open('C:\\Users\\nena_\\.secret\\tmbd_api.json','r') as f:
    login = json.load(f)
#display the keys of the loaded dict 
login.keys()
# Out:
# dict_keys(['api key', 'api read token'])

# %%
#import tmdb package and set the api_key variable to the API key 
import tmdbsimple as tmdb 
tmdb.API_KEY = login['api key']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm_notebook

import os, time,json
import tmdbsimple as tmdb 
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['.ipynb_checkpoints',
#  'combined_api_results.csv.gz',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'final_tmdb_data_2010.csv.gz',
#  'final_tmdb_data_2011.csv.gz',
#  'final_tmdb_data_2012.csv.gz',
#  'final_tmdb_data_2013.csv.gz',
#  'final_tmdb_data_2014.csv.gz',
#  'final_tmdb_data_2015.csv.gz',
#  'final_tmdb_data_2018.csv.gz',
#  'final_tmdb_data_2019.csv.gz',
#  'p4_combined_api_results.csv.gz',
#  'title-akas-us-only.csv',
#  'title.basics.csv.gz',
#  'title.ratings.csv.gz',
#  'title_basics_combined.csv.gz',
#  'tmdb_api_results_2000.json',
#  'tmdb_api_results_2001.json',
#  'tmdb_api_results_2010.json',
#  'tmdb_api_results_2011.json',
#  'tmdb_api_results_2012.json',
#  'tmdb_api_results_2013.json',
#  'tmdb_api_results_2014.json',
#  'tmdb_api_results_2015.json',
#  'tmdb_api_results_2018.json',
#  'tmdb_api_results_2019.json']

# %% [markdown]
# * Your stakeholder wants you to extract the budget, revenue, and MPAA Rating (G/PG/PG-13/R), which is also called "Certification".

# %% [markdown]
# ### Saving the Movie Certification/MPAA Rating

# %% [markdown]
# #### Defining the Function

# %%
def get_movie_with_rating(movie_id):
    
    #get the movie object for the current id 
    movie = tmdb.Movies(movie_id)
    
    #save the .info .releases dictionaries
    info = movie.info()
    
    releases = movie.releases()
    #Loop through countries in releases 
    for c in releases['countries']:
        #if the country abbreviation == US
        if c['iso_3166_1'] == 'US':
            ## Save a certification key in info with the certification 
            info['certification'] = c['certification']
            
    return info

# %%
test = get_movie_with_rating("tt0848228") 
test
# Out:
# {'adult': False,
#  'backdrop_path': '/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg',
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'budget': 220000000,
#  'genres': [{'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'}],
#  'homepage': 'https://www.marvel.com/movies/the-avengers',
#  'id': 24428,
#  'imdb_id': 'tt0848228',
#  'original_language': 'en',
#  'original_title': 'The Avengers',
#  'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#  'popularity': 96.656,
#  'poster_path': '/RYMX2wcKCBAr24UyPD7xwmjaTn.jpg',
# ...

# %%
def write_json(new_data, filename): 
    """Appends a list of records (new_data) to a json file (filename). 
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""  
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)

# %% [markdown]
# ### Read in Title Basics

# %%
# Load in the dataframe from project part 1 as basics:
basics = pd.read_csv('Data/title.basics.csv.gz')

basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                        Lives of Performers        0       2016      NaN
# 3                 The Other Side of the Wind        0       2018      NaN
# 4                          The Naked Monster        0       2005      NaN
#
#    runtimeMinutes                  genres
# ...

# %% [markdown]
# ### Extracting years 2010-2019

# %%
YEARS_TO_GET = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]

# %%
errors = [ ]

# %%
# Start of OUTER loop
for YEAR in tqdm_notebook(YEARS_TO_GET, desc='YEARS', position=0):
    #Defining the JSON File to store results for year
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    # Check if file exists
    file_exists = os.path.isfile(JSON_FILE)


    # If it does not exist: create it
    if file_exists == False:
        
        # save an empty dict with just "imdb_id" to the new json file.
        with open(JSON_FILE,'w') as f:
            
            json.dump([{'imdb_id':0}],f)

    #Saving new year as the current df
    df = basics.loc[ basics['startYear']==YEAR].copy()
    # saving movie ids to list
    movie_ids = df['tconst'].copy()
    movie_ids

    # Load existing data from json into a dataframe called "previous_df"
    previous_df = pd.read_json(JSON_FILE)

    previous_df

    # filter out any ids that are already in the JSON_FILE
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]



    #Get index and movie id from list
    # INNER Loop
    for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
        try:
            # Retrieve then data for the movie id
            temp = get_movie_with_rating(movie_id)  
            # Append/extend results to existing file using a pre-made function
            write_json(temp,JSON_FILE)
            # Short 20 ms sleep to prevent overwhelming server
            time.sleep(0.02)
            
        except Exception as e:
            errors.append([movie_id, e])



    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)
# Out:
# YEARS:   0%|          | 0/1 [00:00<?, ?it/s]
# Movies from 2022: 0it [00:00, ?it/s]

# %%
#Print message reporting back the number of movie ids that caused an error 
print(f"- Total errors: {len(errors)}")
# Out:
# - Total errors: 0

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Load in the dataframe from project part 1 as basics:
yr_2010 = pd.read_csv('Data/final_tmdb_data_2010.csv.gz')

yr_2010.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0312305    0.0  /lqUbt2cy2pnqvxKefbQAtxLS0WA.jpg                   NaN
# 2  tt0326965    0.0  /xt2klJdKCVGXcoBGQrGfAS0aGDE.jpg                   NaN
# 3  tt0331312    0.0                               NaN                   NaN
# 4  tt0393049    0.0  /gc9FN5zohhzCt05RkejQIIPLtBl.jpg                   NaN
#
#      budget                                             genres  \
# 0       NaN                                                NaN
# 1       0.0  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 2       0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 3       0.0                                                 []
# 4  300000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                      homepage        id original_language  \
# 0                         NaN       NaN               NaN
# ...

# %%
# Load in the dataframe from project part 1 as basics:
yr_2011 = pd.read_csv('Data/final_tmdb_data_2011.csv.gz')

yr_2011.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0176694    0.0  /43VrmHOChLcAOG9S5tIFdsxr3u8.jpg                   NaN
# 2  tt0210470    0.0                               NaN                   NaN
# 3  tt0323808    0.0  /oJiBH1aSFv0gOKwb34I7CCKqgRE.jpg                   NaN
# 4  tt0372538    0.0                               NaN                   NaN
#
#       budget                                             genres  \
# 0        NaN                                                NaN
# 1        0.0  [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 2        0.0                [{'id': 99, 'name': 'Documentary'}]
# 3  7750000.0  [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...
# 4  5000000.0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                             homepage        id  \
# ...

# %%
# Load in the dataframe from project part 1 as basics:
yr_2012 = pd.read_csv('Data/final_tmdb_data_2012.csv.gz')

yr_2012.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0249516    0.0  /t7zb6CnRQwhzQSq0apR4ESFYiWN.jpg                   NaN
# 2  tt0285252    0.0  /pKOHinAVIkyqLliMaTHCSL1T4zU.jpg                   NaN
# 3  tt0293069    0.0  /cj2isIuskSePAwpb2D6yUBZrhkJ.jpg                   NaN
# 4  tt0337692    0.0  /jbcjTR19jatK9Jh4yfpNUXwPGh6.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  65000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 2   4000000.0                     [{'id': 35, 'name': 'Comedy'}]
# 3         0.0                   [{'id': 53, 'name': 'Thriller'}]
# 4  25000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
#
#                                             homepage        id  \
# ...

# %%
# Load in the dataframe from project part 1 as basics:
yr_2013 = pd.read_csv('Data/final_tmdb_data_2013.csv.gz')

yr_2013.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0255820    0.0                               NaN                   NaN
# 2  tt0359950    0.0  /8hSjOHRY4OUEpqxszYbMdem8z9C.jpg                   NaN
# 3  tt0409379    0.0  /3tjCnZ9GFLiuMjAHxXAm5Tc98W2.jpg                   NaN
# 4  tt0452183    0.0                               NaN                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1   2000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2  90000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 4         0.0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                             homepage        id  \
# ...

# %%
# Load in the dataframe from project part 1 as basics:
yr_2014 = pd.read_csv('Data/final_tmdb_data_2014.csv.gz')

yr_2014.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0329539    0.0                               NaN                   NaN
# 2  tt0365907    0.0  /isrro0soStk2tSWMsI50lPPhUsU.jpg                   NaN
# 3  tt0403935    0.0  /romORaZvZqMRjTPgw0HrAZpVn9V.jpg                   NaN
# 4  tt0424859    0.0                               NaN                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1         0.0                     [{'id': 35, 'name': 'Comedy'}]      NaN
# 2  28000000.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN
# 3         0.0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...      NaN
# 4         0.0                                                 []      NaN
#
# ...

# %%
# Load in the dataframe from project part 1 as basics:
yr_2015 = pd.read_csv('Data/final_tmdb_data_2015.csv.gz')

yr_2015.head()
# Out:
#      imdb_id  adult                     backdrop_path  \
# 0          0    NaN                               NaN
# 1  tt0369610    0.0  /dF6FjTZzRTENfB4R17HDN20jLT2.jpg
# 2  tt0420293    0.0  /b0p0OPx1ZDZVc8iDB1kle0Cc2H9.jpg
# 3  tt0462335    0.0  /wESuRMxELPAwo56qFRcoyI4p20F.jpg
# 4  tt0478970    0.0  /1K3JmSNUN8OpjYsCjc0Hy0SYxAb.jpg
#
#                                belongs_to_collection       budget  \
# 0                                                NaN          NaN
# 1  {'id': 328, 'name': 'Jurassic Park Collection'...  150000000.0
# 2                                                NaN          0.0
# 3                                                NaN          0.0
# 4  {'id': 422834, 'name': 'Ant-Man Collection', '...  130000000.0
#
#                                               genres  \
# 0                                                NaN
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2                   [{'id': 53, 'name': 'Thriller'}]
# ...

# %%
# Load in the dataframe from project part 1 as basics:
yr_2018 = pd.read_csv('Data/final_tmdb_data_2018.csv.gz')

yr_2018.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0069049    0.0  /wXUcSJG6dqNKgIRgqYqX98UA1wz.jpg                   NaN
# 2  tt0192528    0.0  /gkBxjhtVEqgxOiRwRfWw1j7ez6K.jpg                   NaN
# 3  tt0360556    0.0  /7oy4miyq4WYYy0xtX6lbNVPrEsr.jpg                   NaN
# 4  tt0365545    0.0  /ljTYcQ3pkzYF52Z8ev1Z1UThnPy.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  12000000.0                      [{'id': 18, 'name': 'Drama'}]
# 2   5000000.0                      [{'id': 18, 'name': 'Drama'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 4         0.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
#                                     homepage        id original_language  \
# ...

# %%
# Load in the dataframe from project part 1 as basics:
yr_2019 = pd.read_csv('Data/final_tmdb_data_2019.csv.gz')

yr_2019.head()
# Out:
#      imdb_id  adult                     backdrop_path  \
# 0          0    NaN                               NaN
# 1  tt0385887    0.0  /xMHeU84wLQ9uH9acJ0oPgdii9wO.jpg
# 2  tt0437086    0.0  /8RKBHHRqOMOLh5qW3sS6TSFTd8h.jpg
# 3  tt0441881    0.0  /7uacpbrJd9g9xSTLgfyg1NwkAiu.jpg
# 4  tt0448115    0.0  /o7JVhqMmrex1TPbmuxl8YXVlcfl.jpg
#
#                                belongs_to_collection       budget  \
# 0                                                NaN          NaN
# 1                                                NaN   26000000.0
# 2                                                NaN  170000000.0
# 3                                                NaN   23934823.0
# 4  {'id': 724848, 'name': 'Shazam! Collection', '...   80000000.0
#
#                                               genres  \
# 0                                                NaN
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# ...

# %%
#Concatenate the data into 1 dataframe for the remainder of the analysis.
con_df = pd.concat([yr_2010, yr_2011, yr_2012, yr_2013, yr_2014, yr_2015, yr_2018, yr_2019], ignore_index=True)
con_df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0312305    0.0  /lqUbt2cy2pnqvxKefbQAtxLS0WA.jpg                   NaN
# 2  tt0326965    0.0  /xt2klJdKCVGXcoBGQrGfAS0aGDE.jpg                   NaN
# 3  tt0331312    0.0                               NaN                   NaN
# 4  tt0393049    0.0  /gc9FN5zohhzCt05RkejQIIPLtBl.jpg                   NaN
#
#      budget                                             genres  \
# 0       NaN                                                NaN
# 1       0.0  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 2       0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 3       0.0                                                 []
# 4  300000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                      homepage        id original_language  \
# 0                         NaN       NaN               NaN
# ...

# %%
con_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2599 entries, 0 to 2598
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2599 non-null   object
#  1   adult                  2597 non-null   float64
#  2   backdrop_path          1441 non-null   object
#  3   belongs_to_collection  211 non-null    object
#  4   budget                 2597 non-null   float64
#  5   genres                 2597 non-null   object
#  6   homepage               170 non-null    object
#  7   id                     2597 non-null   float64
#  8   original_language      2597 non-null   object
#  9   original_title         2597 non-null   object
#  10  overview               2553 non-null   object
#  11  popularity             2597 non-null   float64
#  12  poster_path            2355 non-null   object
#  13  production_companies   2597 non-null   object
# ...
